# %% [markdown]
# # TECHNOLOGY MARKET ORDER PROGRAM

# %% [markdown]
# ### Task 1 – Setting up the system.

# %%
'''Use appropriate data structures to store the item code, description and price information for 
the mobile devices, SIM cards and accessories'''

# %%
PRODUCTS=[]

# %%
PRODUCTS.append({"Category": "Phone", "Item_Code": "BPCM", "Description": "Compact", "Price": 29.99})

# %%
PRODUCTS
# Out:
# [{'Category': 'Phone',
#   'Item_Code': 'BPCM',
#   'Description': 'Compact',
#   'Price': 29.99}]

# %%
PRODUCTS.append({"Category": "Phone", "Item_Code": "BPSH", "Description": "Clam shell", "Price": 49.99})

# %%
PRODUCTS.append({"Category": "Phone", "Item_Code": "RPSS", "Description": "Robo phone - 5inch 64GB memory", "Price": 199.99})

# %%
PRODUCTS.append({"Category": "Phone", "Item_Code": "RPLL", "Description": "Robo phone - 6inch 256GB memory", "Price": 499.99})

# %%
PRODUCTS.append({"Category": "Phone", "Item_Code": "YPLS", "Description": "Y-phone standart 6 inch 64GB memory", "Price": 549.99})

# %%
PRODUCTS.append({"Category": "Phone", "Item_Code": "YPLL", "Description": "Y-phone deluxe 6 inch 256GB memory", "Price": 649.99})

# %%
PRODUCTS.append({"Category": "Tablet", "Item_Code": "RTSM", "Description": "RoboTab - 8inch screen 64GB memory", "Price": 149.99})
